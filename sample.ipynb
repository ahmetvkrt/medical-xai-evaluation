# %%
# Out:
# C:\Users\Victus\PycharmProjects\JupyterProject2\medical-xai-evaluation\config.py:1: SyntaxWarning: invalid escape sequence '\V'
#   KAGGLE_DATASET_PATH = "C:\Users\Victus\PycharmProjects\JupyterProject2\data\Kaggle"
# C:\Users\Victus\PycharmProjects\JupyterProject2\medical-xai-evaluation\config.py:2: SyntaxWarning: invalid escape sequence '\V'
#   BRATS_DATASET_PATH = "C:\Users\Victus\PycharmProjects\JupyterProject2\data\Brats\content\data"
# CONFIG OK
# DATA OK
# Train: 5712 Val: 1311
# ...
